# %% [markdown]
# <a href="https://colab.research.google.com/github/dinhln03/VNdatathon-COINCARD-team95/blob/main/B%E1%BA%A3n_sao_c%E1%BB%A7a_lama_cleaner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 1. Install package
#@markdown # 1. Install package
#@markdown Github Project: https://github.com/Sanster/lama-cleaner

# !pip3 install lama-cleaner pyngrok
# Out:
# Collecting lama-cleaner
#   Downloading lama_cleaner-1.2.5-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 16.7 MB/s eta 0:00:00
# Collecting pyngrok
#   Downloading pyngrok-7.0.3-py3-none-any.whl (21 kB)
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from lama-cleaner) (2.1.0+cu121)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from lama-cleaner) (4.8.0.76)
# Collecting flask==2.2.3 (from lama-cleaner)
#   Downloading Flask-2.2.3-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 10.3 MB/s eta 0:00:00
# Collecting flask-socketio (from lama-cleaner)
#   Downloading Flask_SocketIO-5.3.6-py3-none-any.whl (18 kB)
# Collecting simple-websocket (from lama-cleaner)
#   Downloading simple_websocket-1.0.0-py3-none-any.whl (13 kB)
# Collecting flask-cors (from lama-cleaner)
#   Downloading Flask_Cors-4.0.0-py2.py3-none-any.whl (14 kB)
# Collecting flaskwebgui==0.3.5 (from lama-cleaner)
#   Downloading flaskwebgui-0.3.5-py3-none-any.whl (7.9 kB)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from lama-cleaner) (1.10.13)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from lama-cleaner) (13.7.0)
# Collecting loguru (from lama-cleaner)
#   Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 8.4 MB/s eta 0:00:00
# Collecting yacs (from lama-cleaner)
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Collecting diffusers==0.16.1 (from lama-cleaner)
#   Downloading diffusers-0.16.1-py3-none-any.whl (934 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 934.9/934.9 kB 32.1 MB/s eta 0:00:00
# Collecting transformers==4.27.4 (from lama-cleaner)
#   Downloading transformers-4.27.4-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 49.3 MB/s eta 0:00:00
# Collecting gradio (from lama-cleaner)
#   Downloading gradio-4.10.0-py3-none-any.whl (16.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 54.5 MB/s eta 0:00:00
# Collecting piexif==1.1.3 (from lama-cleaner)
#   Downloading piexif-1.1.3-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from lama-cleaner) (0.4.1)
# Collecting omegaconf (from lama-cleaner)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 3.9 MB/s eta 0:00:00
# Collecting controlnet-aux==0.0.3 (from lama-cleaner)
#   Downloading controlnet_aux-0.0.3-py3-none-any.whl (122 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.9/122.9 kB 17.2 MB/s eta 0:00:00
# Collecting werkzeug==2.2.2 (from lama-cleaner)
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.7/232.7 kB 23.4 MB/s eta 0:00:00
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from controlnet-aux==0.0.3->lama-cleaner) (9.4.0)
# Collecting einops (from controlnet-aux==0.0.3->lama-cleaner)
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from controlnet-aux==0.0.3->lama-cleaner) (3.13.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from controlnet-aux==0.0.3->lama-cleaner) (0.19.4)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from controlnet-aux==0.0.3->lama-cleaner) (7.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from controlnet-aux==0.0.3->lama-cleaner) (1.23.5)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from controlnet-aux==0.0.3->lama-cleaner) (0.19.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from controlnet-aux==0.0.3->lama-cleaner) (1.11.4)
# Collecting timm (from controlnet-aux==0.0.3->lama-cleaner)
#   Downloading timm-0.9.12-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 57.6 MB/s eta 0:00:00
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from controlnet-aux==0.0.3->lama-cleaner) (0.16.0+cu121)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.16.1->lama-cleaner) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers==0.16.1->lama-cleaner) (2.31.0)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from flask==2.2.3->lama-cleaner) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from flask==2.2.3->lama-cleaner) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from flask==2.2.3->lama-cleaner) (8.1.7)
# Collecting whichcraft (from flaskwebgui==0.3.5->lama-cleaner)
#   Downloading whichcraft-0.6.1-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.4->lama-cleaner) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.4->lama-cleaner) (6.0.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.27.4->lama-cleaner)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 56.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.27.4->lama-cleaner) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug==2.2.2->lama-cleaner) (2.1.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->lama-cleaner) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->lama-cleaner) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->lama-cleaner) (3.2.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->lama-cleaner) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->lama-cleaner) (2.1.0)
# Collecting python-socketio>=5.0.2 (from flask-socketio->lama-cleaner)
#   Downloading python_socketio-5.10.0-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 kB 5.2 MB/s eta 0:00:00
# Collecting aiofiles<24.0,>=22.0 (from gradio->lama-cleaner)
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->lama-cleaner) (4.2.2)
# Collecting fastapi (from gradio->lama-cleaner)
#   Downloading fastapi-0.105.0-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 7.4 MB/s eta 0:00:00
# Collecting ffmpy (from gradio->lama-cleaner)
#   Downloading ffmpy-0.3.1.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio-client==0.7.3 (from gradio->lama-cleaner)
#   Downloading gradio_client-0.7.3-py3-none-any.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.8/304.8 kB 19.7 MB/s eta 0:00:00
# Collecting httpx (from gradio->lama-cleaner)
#   Downloading httpx-0.25.2-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio->lama-cleaner) (6.1.1)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio->lama-cleaner) (3.7.1)
# Collecting orjson~=3.0 (from gradio->lama-cleaner)
#   Downloading orjson-3.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio->lama-cleaner) (1.5.3)
# Collecting pydantic (from lama-cleaner)
#   Downloading pydantic-2.5.2-py3-none-any.whl (381 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.9/381.9 kB 27.9 MB/s eta 0:00:00
# Collecting pydub (from gradio->lama-cleaner)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting python-multipart (from gradio->lama-cleaner)
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.4 MB/s eta 0:00:00
# Collecting semantic-version~=2.0 (from gradio->lama-cleaner)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting tomlkit==0.12.0 (from gradio->lama-cleaner)
#   Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: typer[all]<1.0,>=0.9 in /usr/local/lib/python3.10/dist-packages (from gradio->lama-cleaner) (0.9.0)
# Collecting uvicorn>=0.14.0 (from gradio->lama-cleaner)
#   Downloading uvicorn-0.24.0.post1-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 5.8 MB/s eta 0:00:00
# Collecting websockets<12.0,>=10.0 (from gradio-client==0.7.3->gradio->lama-cleaner)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 10.4 MB/s eta 0:00:00
# Collecting annotated-types>=0.4.0 (from pydantic->lama-cleaner)
#   Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting pydantic-core==2.14.5 (from pydantic->lama-cleaner)
#   Downloading pydantic_core-2.14.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 55.4 MB/s eta 0:00:00
# Collecting typing-extensions (from torch>=1.9.0->lama-cleaner)
#   Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf->lama-cleaner)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 18.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->lama-cleaner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->lama-cleaner) (2.16.1)
# Collecting wsproto (from simple-websocket->lama-cleaner)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio->lama-cleaner) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio->lama-cleaner) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio->lama-cleaner) (0.12.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->lama-cleaner) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->lama-cleaner) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->lama-cleaner) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->lama-cleaner) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->lama-cleaner) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->lama-cleaner) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->lama-cleaner) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio->lama-cleaner) (2023.3.post1)
# Requirement already satisfied: bidict>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from python-socketio>=5.0.2->flask-socketio->lama-cleaner) (0.22.1)
# Collecting python-engineio>=4.8.0 (from python-socketio>=5.0.2->flask-socketio->lama-cleaner)
#   Downloading python_engineio-4.8.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 9.2 MB/s eta 0:00:00
# Collecting colorama<0.5.0,>=0.4.3 (from typer[all]<1.0,>=0.9->gradio->lama-cleaner)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting shellingham<2.0.0,>=1.3.0 (from typer[all]<1.0,>=0.9->gradio->lama-cleaner)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting h11>=0.8 (from uvicorn>=0.14.0->gradio->lama-cleaner)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio->lama-cleaner) (3.7.1)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi->gradio->lama-cleaner)
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->gradio->lama-cleaner) (2023.11.17)
# Collecting httpcore==1.* (from httpx->gradio->lama-cleaner)
#   Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->gradio->lama-cleaner) (3.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->gradio->lama-cleaner) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->controlnet-aux==0.0.3->lama-cleaner) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.16.1->lama-cleaner) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.16.1->lama-cleaner) (2.0.7)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->controlnet-aux==0.0.3->lama-cleaner) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->controlnet-aux==0.0.3->lama-cleaner) (2023.12.9)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->controlnet-aux==0.0.3->lama-cleaner) (1.5.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.9.0->lama-cleaner) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi->gradio->lama-cleaner) (1.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->lama-cleaner) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->lama-cleaner) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->lama-cleaner) (0.32.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->lama-cleaner) (0.13.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio->lama-cleaner) (1.16.0)
# Building wheels for collected packages: antlr4-python3-runtime, ffmpy
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=73af902da91fb7fe7fb4bcbd7eed85c5d9fb92e68d3928a8e880b8c892ac4a05
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.1-py3-none-any.whl size=5579 sha256=76bb9d0a5804f70e47546ad9962af5bc8d01bb1440265e0768c3f5f8028e1d6c
#   Stored in directory: /root/.cache/pip/wheels/01/a6/d1/1c0828c304a4283b2c1639a09ad86f83d7c487ef34c6b4a1bf
# Successfully built antlr4-python3-runtime ffmpy
# Installing collected packages: whichcraft, tokenizers, pydub, ffmpy, antlr4-python3-runtime, yacs, werkzeug, websockets, typing-extensions, tomlkit, shellingham, semantic-version, python-multipart, pyngrok, piexif, orjson, omegaconf, loguru, h11, flaskwebgui, einops, colorama, annotated-types, aiofiles, wsproto, uvicorn, starlette, pydantic-core, httpcore, flask, transformers, simple-websocket, pydantic, httpx, flask-cors, diffusers, timm, python-engineio, gradio-client, fastapi, python-socketio, gradio, controlnet-aux, flask-socketio, lama-cleaner
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.0
#     Uninstalling tokenizers-0.15.0:
#       Successfully uninstalled tokenizers-0.15.0
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 3.0.1
#     Uninstalling Werkzeug-3.0.1:
#       Successfully uninstalled Werkzeug-3.0.1
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: flask
#     Found existing installation: Flask 2.2.5
#     Uninstalling Flask-2.2.5:
#       Successfully uninstalled Flask-2.2.5
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.2
#     Uninstalling transformers-4.35.2:
#       Successfully uninstalled transformers-4.35.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.13
#     Uninstalling pydantic-1.10.13:
#       Successfully uninstalled pydantic-1.10.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.
# Successfully installed aiofiles-23.2.1 annotated-types-0.6.0 antlr4-python3-runtime-4.9.3 colorama-0.4.6 controlnet-aux-0.0.3 diffusers-0.16.1 einops-0.7.0 fastapi-0.105.0 ffmpy-0.3.1 flask-2.2.3 flask-cors-4.0.0 flask-socketio-5.3.6 flaskwebgui-0.3.5 gradio-4.10.0 gradio-client-0.7.3 h11-0.14.0 httpcore-1.0.2 httpx-0.25.2 lama-cleaner-1.2.5 loguru-0.7.2 omegaconf-2.3.0 orjson-3.9.10 piexif-1.1.3 pydantic-2.5.2 pydantic-core-2.14.5 pydub-0.25.1 pyngrok-7.0.3 python-engineio-4.8.0 python-multipart-0.0.6 python-socketio-5.10.0 semantic-version-2.10.0 shellingham-1.5.4 simple-websocket-1.0.0 starlette-0.27.0 timm-0.9.12 tokenizers-0.13.3 tomlkit-0.12.0 transformers-4.27.4 typing-extensions-4.9.0 uvicorn-0.24.0.post1 websockets-11.0.3 werkzeug-2.2.2 whichcraft-0.6.1 wsproto-1.2.0 yacs-0.1.8

# %%
#@title 2. Download model
#@markdown # 2. Downloading model
init_model = 'lama' #@param ['lama', 'sd1.5', 'paint_by_example']
port = 4242

#@markdown # !! Important Notes !!
#@markdown Please stop this block after model download finish (seeing `running on http://0.0.0.0:4242/` in the log)

# !lama-cleaner --host 0.0.0.0 --port $port --model $init_model
# Out:
# - Platform: Linux-6.1.58+-x86_64-with-glibc2.35
# - Python version: 3.10.12
# - torch: 2.1.0+cu121
# - torchvision: 0.16.0+cu121
# - Pillow: 9.4.0
# - diffusers: 0.16.1
# - transformers: 4.27.4
# - opencv-python: 4.8.0.76
# - xformers: N/A
# - accelerate: N/A
# - lama-cleaner: 1.2.5
# - rembg: N/A
# - realesrgan: N/A
# - gfpgan: N/A
#
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# 2023-12-17 01:52:45.315417: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-17 01:52:45.315487: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-17 01:52:45.316933: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-17 01:52:46.392277: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Downloading: "https://github.com/Sanster/models/releases/download/add_big_lama/big-lama.pt" to /root/.cache/torch/hub/checkpoints/big-lama.pt
# 100% 196M/196M [00:00<00:00, 270MB/s]
# 2023-12-17 01:52:49.537 | INFO     | lama_cleaner.helper:download_model:52 - Download model success, md5: e3aa4aaa15225a33ec84f9f4bc47e500
# 2023-12-17 01:52:49.538 | INFO     | lama_cleaner.helper:load_jit_model:102 - Loading model from: /root/.cache/torch/hub/checkpoints/big-lama.pt
# Running on http://127.0.0.1:4242
#  * Running on http://172.28.0.12:4242
# Press CTRL+C to quit

# %%
#@title 3. Setup ngrok

#@markdown # 3. Setup ngrok
#@markdown Get a free [ngrok](https://ngrok.com/) account and copy your authtoken [here](https://dashboard.ngrok.com/get-started/your-authtoken).
ngrok_authtoken = '2ZUg9Yt6wtmR8eLVYYq1C15y2Ns_wJxxQg8KgimUmbuq8FPK' #@param {type: 'string'}

# !ngrok authtoken $ngrok_authtoken

from pyngrok import ngrok
public_url = ngrok.connect(port).public_url
print(f"ngrok public url: {public_url}.")
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# ngrok public url: https://bd2f-35-230-19-174.ngrok-free.app.

# %%
#@title 4. Start Lama Cleaner server
#@markdown # 4. Start Lama Cleaner server
#@markdown When you see `Running on http://0.0.0.0:4242/' in the log`, please open **ngrok public link**


# !lama-cleaner --host 0.0.0.0 --port $port --model $init_model
# Out:
# - Platform: Linux-6.1.58+-x86_64-with-glibc2.35
# - Python version: 3.10.12
# - torch: 2.1.0+cu121
# - torchvision: 0.16.0+cu121
# - Pillow: 9.4.0
# - diffusers: 0.16.1
# - transformers: 4.27.4
# - opencv-python: 4.8.0.76
# - xformers: N/A
# - accelerate: N/A
# - lama-cleaner: 1.2.5
# - rembg: N/A
# - realesrgan: N/A
# - gfpgan: N/A
#
# 2023-12-17 02:05:16.424934: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-17 02:05:16.424986: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-17 02:05:16.426265: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-17 02:05:17.531644: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-12-17 02:05:19.117 | INFO     | lama_cleaner.helper:load_jit_model:102 - Loading model from: /root/.cache/torch/hub/checkpoints/big-lama.pt
# Running on http://127.0.0.1:4242
#  * Running on http://172.28.0.12:4242
# Press CTRL+C to quit
# 127.0.0.1 - - [17/Dec/2023 02:05:24] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2023 02:05:25] "GET /static/js/main.1fda6320.js HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2023 02:05:25] "GET /static/css/main.ce986cc8.css HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2023 02:05:27] "GET /inputimage HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2023 02:05:27] "GET /model HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2023 02:05:27] "GET /server_config HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2023 02:05:27] "GET /static/media/Inter-roman.var.ba4caefcdf5b36b438db.woff2 HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2023 02:05:27] "GET /is_desktop HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2023 02:05:29] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [17/Dec/2023 02:05:45] "GET /model HTTP/1.1" 200 -
